# %% [markdown]
# # plotly dashを検証する

# %% [markdown]
# ### インストール

# %% [markdown]
# [plotly公式: Dash Installation](https://dash.plotly.com/installation)

# %% [markdown]
# ```
# pip install dash pandas
# ```

# %% [markdown]
# ### サンプルプロジェクト

# %% [markdown]
# [plotly公式: A Minimal Dash App](https://dash.plotly.com/minimal-app)

# %%
from dash import Dash, html, dcc, callback, Output, Input
import plotly.express as px
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/gapminder_unfiltered.csv')

app = Dash(__name__)

app.layout = html.Div([
    html.H1(children='Title of Dash App', style={'textAlign':'center'}),
    dcc.Dropdown(df.country.unique(), 'Canada', id='dropdown-selection'),
    dcc.Graph(id='graph-content')
])

@callback(
    Output('graph-content', 'figure'),
    Input('dropdown-selection', 'value')
)
def update_graph(value):
    dff = df[df.country==value]
    return px.line(dff, x='year', y='pop')

if __name__ == '__main__':
    app.run(debug=True)

# %% [markdown]
# ### チュートリアル

# %% [markdown]
# [plotly公式: Dash in 20 Minutes](https://dash.plotly.com/tutorial)

# %%
import pandas as pd

df = pd.read_parquet("./export/export.xml.parquet")
df.head(100)
# Out:
#                                               type sourceName sourceVersion  \
# 0   HKQuantityTypeIdentifierDistanceWalkingRunning       FUJI          10.0
# 1   HKQuantityTypeIdentifierDistanceWalkingRunning       FUJI          10.0
# 2   HKQuantityTypeIdentifierDistanceWalkingRunning       FUJI          10.0
# 3   HKQuantityTypeIdentifierDistanceWalkingRunning       FUJI          10.0
# 4   HKQuantityTypeIdentifierDistanceWalkingRunning       FUJI          10.0
# ..                                             ...        ...           ...
# 95  HKQuantityTypeIdentifierDistanceWalkingRunning       FUJI          10.0
# 96  HKQuantityTypeIdentifierDistanceWalkingRunning       FUJI          10.0
# 97  HKQuantityTypeIdentifierDistanceWalkingRunning       FUJI          10.0
# 98  HKQuantityTypeIdentifierDistanceWalkingRunning       FUJI          10.0
# 99  HKQuantityTypeIdentifierDistanceWalkingRunning       FUJI          10.0
#
#                                                device unit  \
# 0   <<HKDevice: 0x28087f020>, name:iPhone, manufac...   km
# 1   <<HKDevice: 0x28087f020>, name:iPhone, manufac...   km
# 2   <<HKDevice: 0x28087f020>, name:iPhone, manufac...   km
# 3   <<HKDevice: 0x28087f020>, name:iPhone, manufac...   km
# 4   <<HKDevice: 0x28087f020>, name:iPhone, manufac...   km
# ..                                                ...  ...
# 95  <<HKDevice: 0x28087f020>, name:iPhone, manufac...   km
# 96  <<HKDevice: 0x28087f020>, name:iPhone, manufac...   km
# 97  <<HKDevice: 0x28087f020>, name:iPhone, manufac...   km
# 98  <<HKDevice: 0x28087f020>, name:iPhone, manufac...   km
# 99  <<HKDevice: 0x28087f020>, name:iPhone, manufac...   km
#
#                  creationDate                  startDate  \
# 0   2016-11-11 21:52:49 +0900  2016-11-11 20:42:10 +0900
# 1   2016-11-11 21:52:49 +0900  2016-11-11 20:50:00 +0900
# 2   2016-11-11 21:52:49 +0900  2016-11-11 20:59:51 +0900
# 3   2016-11-11 21:52:49 +0900  2016-11-11 21:09:02 +0900
# 4   2016-11-11 21:52:49 +0900  2016-11-11 21:13:55 +0900
# ..                        ...                        ...
# 95  2016-11-16 07:46:27 +0900  2016-11-16 07:33:45 +0900
# 96  2016-11-16 08:45:40 +0900  2016-11-16 07:43:44 +0900
# 97  2016-11-16 08:45:40 +0900  2016-11-16 07:53:15 +0900
# 98  2016-11-16 08:45:40 +0900  2016-11-16 07:59:20 +0900
# 99  2016-11-16 08:45:40 +0900  2016-11-16 08:07:42 +0900
#
#                       endDate    value   sum
# 0   2016-11-11 20:50:00 +0900   0.0308  None
# 1   2016-11-11 20:59:51 +0900  0.18041  None
# 2   2016-11-11 21:09:02 +0900  0.22598  None
# 3   2016-11-11 21:13:55 +0900  0.10113  None
# 4   2016-11-11 21:22:11 +0900  0.00975  None
# ..                        ...      ...   ...
# 95  2016-11-16 07:43:44 +0900  0.22296  None
# 96  2016-11-16 07:49:26 +0900  0.07324  None
# 97  2016-11-16 07:59:20 +0900  0.00966  None
# 98  2016-11-16 08:03:38 +0900  0.00528  None
# 99  2016-11-16 08:14:03 +0900   0.0346  None
#
# [100 rows x 10 columns]

# %%
import pandas as pd

df = pd.read_csv("./export/export.xml.csv")
df.head(100)
# Out:
#                     startDate                    endDate    value unit  \
# 0   2016-11-11 20:42:10 +0900  2016-11-11 20:50:00 +0900  0.03080   km
# 1   2016-11-11 20:50:00 +0900  2016-11-11 20:59:51 +0900  0.18041   km
# 2   2016-11-11 20:59:51 +0900  2016-11-11 21:09:02 +0900  0.22598   km
# 3   2016-11-11 21:09:02 +0900  2016-11-11 21:13:55 +0900  0.10113   km
# 4   2016-11-11 21:13:55 +0900  2016-11-11 21:22:11 +0900  0.00975   km
# ..                        ...                        ...      ...  ...
# 95  2016-11-16 07:33:45 +0900  2016-11-16 07:43:44 +0900  0.22296   km
# 96  2016-11-16 07:43:44 +0900  2016-11-16 07:49:26 +0900  0.07324   km
# 97  2016-11-16 07:53:15 +0900  2016-11-16 07:59:20 +0900  0.00966   km
# 98  2016-11-16 07:59:20 +0900  2016-11-16 08:03:38 +0900  0.00528   km
# 99  2016-11-16 08:07:42 +0900  2016-11-16 08:14:03 +0900  0.03460   km
#
#                                                device
# 0   <<HKDevice: 0x28087f020>, name:iPhone, manufac...
# 1   <<HKDevice: 0x28087f020>, name:iPhone, manufac...
# 2   <<HKDevice: 0x28087f020>, name:iPhone, manufac...
# 3   <<HKDevice: 0x28087f020>, name:iPhone, manufac...
# 4   <<HKDevice: 0x28087f020>, name:iPhone, manufac...
# ..                                                ...
# 95  <<HKDevice: 0x28087f020>, name:iPhone, manufac...
# 96  <<HKDevice: 0x28087f020>, name:iPhone, manufac...
# 97  <<HKDevice: 0x28087f020>, name:iPhone, manufac...
# 98  <<HKDevice: 0x28087f020>, name:iPhone, manufac...
# 99  <<HKDevice: 0x28087f020>, name:iPhone, manufac...
#
# [100 rows x 5 columns]
